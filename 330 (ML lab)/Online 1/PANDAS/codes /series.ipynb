# %%
import pandas as pd
print(pd.__version__)

# %%
df= pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Nickname':['nengtu','pengtu','chengtu']
})

df= df.set_index('Name')
df
# Out:
#          Age Nickname
# Name
# Alice     25   nengtu
# Bob       30   pengtu
# Charlie   35  chengtu

# %%
values = [23,4,22332]
series = pd.Series(values)
series
