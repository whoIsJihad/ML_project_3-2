# %%
import numpy as np
arr= np.array([3,5.6,2.2,6.4234])
print(arr, arr.dtype)

# %%
int_array= arr.astype(int)
int_array

# %%
arr_list= arr.tolist()
print(type(arr))
print(type(arr_list))

# %%
print(arr.size)
print(arr.shape)

# %%
np.info(np.eye)
