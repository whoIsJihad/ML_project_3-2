# %%
import numpy as np

one_dim_array=np.array([2,3,4])
two_dim_array=np.array([
    [3,4,5],[7,8,9]
])
three_dim_array=np.array([
    [[3,4,5],[7,8,9]],
    [[6,4,5],[342,8,945]],
    [[26,4,5443],[2,8,45]]
])

print(one_dim_array)
print(two_dim_array)
print(three_dim_array)

# %%
ones_array= np.ones((3,4,))
ones_array

# %%
zeros_array= np.zeros((3,))
zeros_array

# %%
# identity matrix 
identity_mat= np.eye(5)
identity_mat

# %%
# linspace 
linearly_spaced_points = np.linspace(0,100,6)
linearly_spaced_points

# %%
# range with step
arange= np.arange(0,100,6)
arange

# %%
# initialised array with single sacaler
full_array= np.full((2,5,6),3)
full_array

# %%
# random float from 0-1
random_array= np.random.rand(2,3,)
random_array

# %%
random_int= np.random.randint(low=3,high=34,size=(4,5))
random_int
